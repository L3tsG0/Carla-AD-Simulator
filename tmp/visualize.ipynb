# %%
import numpy as np
cost = np.load("/home/tsuruoka/hdd/BEV/CarlaRunner/DrivingAgent/notebooks/tmp/pipeline/run_1764564861/pred_c_dense_1764564861.npy")
print(cost.min(), cost.max())
print(np.count_nonzero(cost))
# Out:
# 0 16
# 3504

# %%
import numpy as np
import matplotlib.pyplot as plt

cost = np.load("window.npy")
plt.figure(figsize=(5, 5))
plt.imshow(cost, cmap="hot", origin="lower")
plt.colorbar()
plt.title("run_1764556167_cost")
plt.show()

# %%
import json, numpy as np, pathlib as pl

cw = json.load(open("/home/tsuruoka/hdd/BEV/CarlaRunner/DrivingAgent/notebooks/class_weight.json"))
print(cw)

# costmap_window に重みが効いているかのチェック
cm = np.load("/home/tsuruoka/hdd/BEV/CarlaRunner/DrivingAgent/notebooks/tmp/pipeline/run_1764818784/costmap_ego_1764818784.npy")
print("min/max:", cm.min(), cm.max())
print("unique tail:", np.unique(cm)[-5:])
# Out:
# {'0': {'name': 'empty', 'weight': 0.0}, '1': {'name': 'barrier', 'weight': 1.0}, '2': {'name': 'bicycle', 'weight': 3.0}, '3': {'name': 'bus', 'weight': 3.0}, '4': {'name': 'car', 'weight': 3.0}, '5': {'name': 'construction', 'weight': 1.0}, '6': {'name': 'motorcycle', 'weight': 3.0}, '7': {'name': 'pedestrian', 'weight': 3.0}, '8': {'name': 'trafficcone', 'weight': 1.0}, '9': {'name': 'trailer', 'weight': 3.0}, '10': {'name': 'truck', 'weight': 3.0}, '11': {'name': 'driveable_surface', 'weight': 0.5}, '12': {'name': 'other_flat', 'weight': 1.0}, '13': {'name': 'sidewalk', 'weight': 1.0}, '14': {'name': 'terrain', 'weight': 0.0}, '15': {'name': 'manmade', 'weight': 1.0}, '16': {'name': 'vegetation', 'weight': 0.0}}
# min/max: 0.0 4.0
# unique tail: [0. 1. 2. 3. 4.]
